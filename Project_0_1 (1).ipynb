# %% [markdown]
# ##Load libraries

# %% [markdown]
# ##Importing the required libraries for EDA

# %% [markdown]
# Below are the libraries that are used in order to perform EDA (Exploratory data analysis)

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# We are going to load a necessary libraries

# %%
import pandas as pd
df=pd.read_csv("/content/laptop price.csv")
print(df.to_string())
# Out:
#      Unnamed: 0.1  Unnamed: 0      brand                                                                         name   price  spec_rating                          processor                              CPU   Ram Ram_type    ROM   ROM_type                                              GPU  display_size  resolution_width  resolution_height                  OS  warranty
# 0               0           0         HP                                             Victus 15-fb0157AX Gaming Laptop   49900    73.000000          5th Gen AMD Ryzen 5 5600H            Hexa Core, 12 Threads   8GB     DDR4  512GB        SSD                          4GB AMD Radeon RX 6500M         15.60            1920.0             1080.0       Windows 11 OS         1
# ...

# %% [markdown]
# ##Load head

# %% [markdown]
# loading head

# %%
print(df.head(5))
# Out:
#    Unnamed: 0.1  Unnamed: 0   brand                                  name  \
# 0             0           0      HP      Victus 15-fb0157AX Gaming Laptop
# 1             1           1      HP                   15s-fq5007TU Laptop
# 2             2           2    Acer                  One 14 Z8-415 Laptop
# 3             3           3  Lenovo  Yoga Slim 6 14IAP8 82WU0095IN Laptop
# 4             4           4   Apple       MacBook Air 2020 MGND3HN Laptop
#
#    price  spec_rating                      processor  \
# 0  49900    73.000000      5th Gen AMD Ryzen 5 5600H
# 1  39900    60.000000   12th Gen Intel Core i3 1215U
# 2  26990    69.323529  11th Gen Intel Core i3 1115G4
# 3  59729    66.000000   12th Gen Intel Core i5 1240P
# 4  69990    69.323529                       Apple M1
#
#                               CPU   Ram Ram_type    ROM ROM_type  \
# 0           Hexa Core, 12 Threads   8GB     DDR4  512GB      SSD
# 1  Hexa Core (2P + 4E), 8 Threads   8GB     DDR4  512GB      SSD
# ...

# %% [markdown]
# ##Load tail

# %% [markdown]
# We are going to loading tail

# %%
print(df.tail(5))
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand  \
# 888           926        1015  Asus
# 889           927        1016  Asus
# 890           928        1017  Asus
# 891           929        1018  Asus
# 892           930        1019  Asus
#
#                                                   name   price  spec_rating  \
# 888          Vivobook 15X 2023 K3504VAB-NJ321WS Laptop   44990    69.323529
# 889                     TUF A15 FA577RM-HQ032WS Laptop  110000    71.000000
# 890  ROG Zephyrus G14 2023 GA402XV-N2034WS Gaming L...  189990    89.000000
# 891  TUF Gaming F15 2023 FX507VU-LP083WS Gaming Laptop  129990    73.000000
# 892  TUF Gaming A15 2023 FA577XU-LP041WS Gaming Laptop  131990    84.000000
#
#                          processor                             CPU   Ram  \
# 888  13th Gen ‎Intel Core i3 1315U  Hexa Core (2P + 4E), 8 Threads   8GB
# 889      6th Gen AMD Ryzen 7 6800H           Octa Core, 16 Threads  16GB
# ...

# %% [markdown]
# ##Loading Datatypes

# %% [markdown]
# Identifying datatypes

# %%
import pandas as pd
df = pd.read_csv("/content/laptop price.csv")
df.dtypes
# Out:
# Unnamed: 0.1           int64
# Unnamed: 0             int64
# brand                 object
# name                  object
# price                  int64
# spec_rating          float64
# processor             object
# CPU                   object
# Ram                   object
# Ram_type              object
# ROM                   object
# ROM_type              object
# GPU                   object
# display_size         float64
# resolution_width     float64
# resolution_height    float64
# OS                    object
# warranty               int64
# dtype: object

# %% [markdown]
# ##LOAD COLUMNS

# %% [markdown]
# Here we are loading some column

# %%
import pandas as pd
df=pd.read_csv("/content/laptop price.csv")
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'brand', 'name', 'price', 'spec_rating',
#        'processor', 'CPU', 'Ram', 'Ram_type', 'ROM', 'ROM_type', 'GPU',
#        'display_size', 'resolution_width', 'resolution_height', 'OS',
#        'warranty'],
#       dtype='object')

# %% [markdown]
# ##loading datatypes

# %% [markdown]
# Here we are loading datatypes

# %%
import pandas as pd
df=pd.read_csv("/content/laptop price.csv")
df.dtypes
# Out:
# Unnamed: 0.1           int64
# Unnamed: 0             int64
# brand                 object
# name                  object
# price                  int64
# spec_rating          float64
# processor             object
# CPU                   object
# Ram                   object
# Ram_type              object
# ROM                   object
# ROM_type              object
# GPU                   object
# display_size         float64
# resolution_width     float64
# resolution_height    float64
# OS                    object
# warranty               int64
# dtype: object

# %% [markdown]
# ##Load Info

# %% [markdown]
# loading info

# %%
import pandas as pd
df=pd.read_csv("/content/laptop price.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       893 non-null    int64
#  1   Unnamed: 0         893 non-null    int64
#  2   brand              893 non-null    object
#  3   name               893 non-null    object
#  4   price              893 non-null    int64
#  5   spec_rating        893 non-null    float64
#  6   processor          893 non-null    object
#  7   CPU                893 non-null    object
#  8   Ram                893 non-null    object
#  9   Ram_type           893 non-null    object
#  10  ROM                893 non-null    object
#  11  ROM_type           893 non-null    object
#  12  GPU                893 non-null    object
#  13  display_size       893 non-null    float64
#  14  resolution_width   893 non-null    float64
#  15  resolution_height  893 non-null    float64
# ...

# %% [markdown]
# ##Dropping irrelevant columns

# %% [markdown]
# Here we are dropping irrelevent column

# %%
df.drop(['price','spec_rating','display_size','resolution_width','resolution_height'],axis=1)
df.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0   brand                                  name  \
# 0             0           0      HP      Victus 15-fb0157AX Gaming Laptop
# 1             1           1      HP                   15s-fq5007TU Laptop
# 2             2           2    Acer                  One 14 Z8-415 Laptop
# 3             3           3  Lenovo  Yoga Slim 6 14IAP8 82WU0095IN Laptop
# 4             4           4   Apple       MacBook Air 2020 MGND3HN Laptop
#
#    price  spec_rating                      processor  \
# 0  49900    73.000000      5th Gen AMD Ryzen 5 5600H
# 1  39900    60.000000   12th Gen Intel Core i3 1215U
# 2  26990    69.323529  11th Gen Intel Core i3 1115G4
# 3  59729    66.000000   12th Gen Intel Core i5 1240P
# 4  69990    69.323529                       Apple M1
#
#                               CPU   Ram Ram_type    ROM ROM_type  \
# 0           Hexa Core, 12 Threads   8GB     DDR4  512GB      SSD
# 1  Hexa Core (2P + 4E), 8 Threads   8GB     DDR4  512GB      SSD
# ...

# %% [markdown]
# ##Renaming the columns

# %% [markdown]
# Most of the column names are very confusing to read, so I just tweaked their column names. This is a good approach it improves the readability of the data set

# %%
df = df.rename(columns={"name":"Name","price":"rate","spec_rating":"spec","processor":"P","CPU":"central processing unit","ROM":"read only memory"})
df.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0   brand                                  Name  \
# 0             0           0      HP      Victus 15-fb0157AX Gaming Laptop
# 1             1           1      HP                   15s-fq5007TU Laptop
# 2             2           2    Acer                  One 14 Z8-415 Laptop
# 3             3           3  Lenovo  Yoga Slim 6 14IAP8 82WU0095IN Laptop
# 4             4           4   Apple       MacBook Air 2020 MGND3HN Laptop
#
#     rate       spec                              P  \
# 0  49900  73.000000      5th Gen AMD Ryzen 5 5600H
# 1  39900  60.000000   12th Gen Intel Core i3 1215U
# 2  26990  69.323529  11th Gen Intel Core i3 1115G4
# 3  59729  66.000000   12th Gen Intel Core i5 1240P
# 4  69990  69.323529                       Apple M1
#
#           central processing unit   Ram Ram_type read only memory ROM_type  \
# 0           Hexa Core, 12 Threads   8GB     DDR4            512GB      SSD
# ...

# %% [markdown]
# ##Null values

# %% [markdown]
# recognize and Treat missing values and outliers

# %%
df.isnull()
# Out:
#      Unnamed: 0.1  Unnamed: 0  brand   name  price  spec_rating  processor  \
# 0           False       False  False  False  False        False      False
# 1           False       False  False  False  False        False      False
# 2           False       False  False  False  False        False      False
# 3           False       False  False  False  False        False      False
# 4           False       False  False  False  False        False      False
# ..            ...         ...    ...    ...    ...          ...        ...
# 888         False       False  False  False  False        False      False
# 889         False       False  False  False  False        False      False
# 890         False       False  False  False  False        False      False
# 891         False       False  False  False  False        False      False
# 892         False       False  False  False  False        False      False
#
#        CPU    Ram  Ram_type    ROM  ROM_type    GPU  display_size  \
# ...

# %% [markdown]
# ##DUPLICATE

# %% [markdown]
# Find any duplicate row and delete them if found.

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 888    False
# 889    False
# 890    False
# 891    False
# 892    False
# Length: 893, dtype: bool

# %% [markdown]
# ##Remove duplicate values

# %% [markdown]
# Remove duplicate values of a variable in a Pandas Dataframe

# %%
rem_dup=df.drop_duplicates(['price','spec_rating'])
print(rem_dup)
# Out:
#      Unnamed: 0.1  Unnamed: 0   brand  \
# 0               0           0      HP
# 1               1           1      HP
# 2               2           2    Acer
# 3               3           3  Lenovo
# 4               4           4   Apple
# ..            ...         ...     ...
# 885           923        1012    Dell
# 889           927        1016    Asus
# 890           928        1017    Asus
# 891           929        1018    Asus
# 892           930        1019    Asus
#
#                                                   name   price  spec_rating  \
# 0                     Victus 15-fb0157AX Gaming Laptop   49900    73.000000
# 1                                  15s-fq5007TU Laptop   39900    60.000000
# 2                                 One 14 Z8-415 Laptop   26990    69.323529
# 3                 Yoga Slim 6 14IAP8 82WU0095IN Laptop   59729    66.000000
# 4                      MacBook Air 2020 MGND3HN Laptop   69990    69.323529
# ...

# %% [markdown]
# ##dropping the duplicate rows

# %% [markdown]
# dropping the duplicate rows in a dataset

# %%
df.shape
# Out:
# (893, 18)

# %% [markdown]
# ##Load count

# %% [markdown]
# Use to count  number of rows

# %%
df.count()
# Out:
# Unnamed: 0.1               893
# Unnamed: 0                 893
# brand                      893
# Name                       893
# rate                       893
# spec                       893
# P                          893
# central processing unit    893
# Ram                        893
# Ram_type                   893
# read only memory           893
# ROM_type                   893
# GPU                        893
# display_size               893
# resolution_width           893
# resolution_height          893
# OS                         893
# warranty                   893
# dtype: int64

# %% [markdown]
# ##load groupby

# %% [markdown]
# here we have groupby items

# %%
import pandas as pd
df = pd.read_csv("/content/laptop price.csv")
df.groupby
# Out:
# <bound method DataFrame.groupby of      Unnamed: 0.1  Unnamed: 0   brand  \
# 0               0           0      HP
# 1               1           1      HP
# 2               2           2    Acer
# 3               3           3  Lenovo
# 4               4           4   Apple
# ..            ...         ...     ...
# 888           926        1015    Asus
# 889           927        1016    Asus
# 890           928        1017    Asus
# 891           929        1018    Asus
# 892           930        1019    Asus
#
#                                                   name   price  spec_rating  \
# 0                     Victus 15-fb0157AX Gaming Laptop   49900    73.000000
# 1                                  15s-fq5007TU Laptop   39900    60.000000
# 2                                 One 14 Z8-415 Laptop   26990    69.323529
# 3                 Yoga Slim 6 14IAP8 82WU0095IN Laptop   59729    66.000000
# 4                      MacBook Air 2020 MGND3HN Laptop   69990    69.323529
# ...

# %% [markdown]
# ##Dropping the duplicate rows

# %% [markdown]
# Dropping the duplicate rows in a dataset

# %%
df.shape
# Out:
# (893, 18)

# %% [markdown]
# ##Drop Missing or Null Values

# %% [markdown]
# The idea of this step is to drop any missing values that are found in the data. So first let's check for any missing value.

# %%
df.isnull().sum()

# %% [markdown]
# ##Load count

# %% [markdown]
# Used to count the number of rows

# %%
df.count()
# Out:
# Unnamed: 0.1         893
# Unnamed: 0           893
# brand                893
# name                 893
# price                893
# spec_rating          893
# processor            893
# CPU                  893
# Ram                  893
# Ram_type             893
# ROM                  893
# ROM_type             893
# GPU                  893
# display_size         893
# resolution_width     893
# resolution_height    893
# OS                   893
# warranty             893
# dtype: int64

# %% [markdown]
# ##Null values

# %% [markdown]
# Dropping the missing or null values in the dataset

# %%
df.isnull()

# %% [markdown]
# ##unique values

# %% [markdown]
# Given below are number of unique values of the Columns

# %%
df.nunique()
# Out:
# Unnamed: 0.1         893
# Unnamed: 0           893
# brand                 30
# name                 815
# price                464
# spec_rating           30
# processor            184
# CPU                   29
# Ram                    7
# Ram_type              12
# ROM                    7
# ROM_type               2
# GPU                  134
# display_size          18
# resolution_width      18
# resolution_height     22
# OS                    14
# warranty               4
# dtype: int64

# %% [markdown]
# ##Selection on row wise and column wise

# %% [markdown]
# below are the data showing selection on row wise and column wise.

# %%
df.iloc[:,[3,6,8,12,]]
# Out:
#                                                   name  \
# 0                     Victus 15-fb0157AX Gaming Laptop
# 1                                  15s-fq5007TU Laptop
# 2                                 One 14 Z8-415 Laptop
# 3                 Yoga Slim 6 14IAP8 82WU0095IN Laptop
# 4                      MacBook Air 2020 MGND3HN Laptop
# ..                                                 ...
# 888          Vivobook 15X 2023 K3504VAB-NJ321WS Laptop
# 889                     TUF A15 FA577RM-HQ032WS Laptop
# 890  ROG Zephyrus G14 2023 GA402XV-N2034WS Gaming L...
# 891  TUF Gaming F15 2023 FX507VU-LP083WS Gaming Laptop
# 892  TUF Gaming A15 2023 FA577XU-LP041WS Gaming Laptop
#
#                          processor   Ram                            GPU
# 0        5th Gen AMD Ryzen 5 5600H   8GB        4GB AMD Radeon RX 6500M
# 1     12th Gen Intel Core i3 1215U   8GB             Intel UHD Graphics
# 2    11th Gen Intel Core i3 1115G4   8GB         Intel Iris Xe Graphics
# ...

# %% [markdown]
# ##FILTERING DATAFRAME

# %% [markdown]
# Here will get all rows having Sales greater or equal to  price <350

# %%
df1= df[df["price"]>350]
df1
# Out:
#      Unnamed: 0.1  Unnamed: 0   brand  \
# 0               0           0      HP
# 1               1           1      HP
# 2               2           2    Acer
# 3               3           3  Lenovo
# 4               4           4   Apple
# ..            ...         ...     ...
# 888           926        1015    Asus
# 889           927        1016    Asus
# 890           928        1017    Asus
# 891           929        1018    Asus
# 892           930        1019    Asus
#
#                                                   name   price  spec_rating  \
# 0                     Victus 15-fb0157AX Gaming Laptop   49900    73.000000
# 1                                  15s-fq5007TU Laptop   39900    60.000000
# 2                                 One 14 Z8-415 Laptop   26990    69.323529
# 3                 Yoga Slim 6 14IAP8 82WU0095IN Laptop   59729    66.000000
# 4                      MacBook Air 2020 MGND3HN Laptop   69990    69.323529
# ...

# %% [markdown]
# Here will get all rows having Sales greater or equal to spec_rating>30

# %%
df1= df[df["spec_rating"]>30]
df1
# Out:
#      Unnamed: 0.1  Unnamed: 0   brand  \
# 0               0           0      HP
# 1               1           1      HP
# 2               2           2    Acer
# 3               3           3  Lenovo
# 4               4           4   Apple
# ..            ...         ...     ...
# 888           926        1015    Asus
# 889           927        1016    Asus
# 890           928        1017    Asus
# 891           929        1018    Asus
# 892           930        1019    Asus
#
#                                                   name   price  spec_rating  \
# 0                     Victus 15-fb0157AX Gaming Laptop   49900    73.000000
# 1                                  15s-fq5007TU Laptop   39900    60.000000
# 2                                 One 14 Z8-415 Laptop   26990    69.323529
# 3                 Yoga Slim 6 14IAP8 82WU0095IN Laptop   59729    66.000000
# 4                      MacBook Air 2020 MGND3HN Laptop   69990    69.323529
# ...

# %% [markdown]
# ####==,&&,>

# %% [markdown]
# Here, we get all rows having brand or rom type is equal to and price > 300 of data frame.

# %%
df.loc[(df['brand']=='Acer')&(df['ROM_type']=='SSD')&(df['price']>300)]
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand  \
# 2               2           2  Acer
# 5               5           5  Acer
# 7               7           7  Acer
# 22             23          23  Acer
# 27             28          29  Acer
# ..            ...         ...   ...
# 875           913        1002  Acer
# 879           917        1006  Acer
# 881           919        1008  Acer
# 886           924        1013  Acer
# 887           925        1014  Acer
#
#                                              name   price  spec_rating  \
# 2                            One 14 Z8-415 Laptop   26990    69.323529
# 5                         Extensa EX214-53 Laptop   39990    62.000000
# 7             Nitro V ANV15-51 2023 Gaming Laptop   76990    63.000000
# 22   Aspire 7 A715-76G UN.QMYSI.002 Gaming Laptop   54990    72.000000
# 27                Extensa 15 EX215-33 2023 Laptop   28990    69.323529
# ..                                            ...     ...          ...
# ...

# %%
df.loc[(df['brand']=='HP')&(df['ROM_type']=='Hard-Disk')&(df['price']>3000)]
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand                            name  price  \
# 136           140         154    HP  Chromebook 15a-na0012TU Laptop  23990
# 202           208         236    HP             15s-du3614TU Laptop  42200
# 351           370         411    HP  Chromebook 15a-na0012TU Laptop  15990
# 444           465         529    HP             15s-dr3506TU Laptop  35999
# 445           466         530    HP             15s-du3614TU Laptop  41710
# 478           500         566    HP             15s-GR0012AU Laptop  37290
#
#      spec_rating                      processor                   CPU  Ram  \
# 136    69.323529           Intel Celeron  N4500  Dual Core, 2 Threads  4GB
# 202    65.000000  11th Gen Intel Core i3 1115G4  Dual Core, 4 Threads  8GB
# 351    69.323529           Intel Celeron  N4500  Dual Core, 2 Threads  4GB
# 444    60.000000  11th Gen Intel Core i3 1115G4  Dual Core, 4 Threads  8GB
# ...

# %% [markdown]
# ##correlation plot

# %% [markdown]
# here we are finding correlation

# %%
import pandas as pd
df = pd.read_csv("/content/laptop price.csv")
df.corr()
# Out:
# <ipython-input-17-f3fcb2a0d558>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    Unnamed: 0.1  Unnamed: 0     price  spec_rating  \
# Unnamed: 0.1           1.000000    0.999665  0.162473     0.109777
# Unnamed: 0             0.999665    1.000000  0.162619     0.108691
# price                  0.162473    0.162619  1.000000     0.546391
# spec_rating            0.109777    0.108691  0.546391     1.000000
# display_size          -0.018512   -0.019570  0.233815     0.274206
# resolution_width       0.028406    0.028244  0.586042     0.337649
# resolution_height      0.069297    0.069869  0.604748     0.328525
# warranty               0.157482    0.158614  0.117101     0.109501
#
#                    display_size  resolution_width  resolution_height  warranty
# ...

# %% [markdown]
# ##Showing Basis Stastics

# %% [markdown]
# Now that younhave seen than what data types are in your dataset,its's time to get an overciew of the value each column constrains

# %%
df.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0          price  spec_rating  display_size  \
# count    893.000000   893.000000     893.000000   893.000000    893.000000
# mean     467.135498   521.382979   79907.409854    69.379026     15.173751
# std      270.209769   299.916605   60880.043823     5.541555      0.939095
# min        0.000000     0.000000    9999.000000    60.000000     11.600000
# 25%      235.000000   265.000000   44500.000000    66.000000     14.000000
# 50%      467.000000   531.000000   61990.000000    69.323529     15.600000
# 75%      702.000000   784.000000   90990.000000    71.000000     15.600000
# max      930.000000  1019.000000  450039.000000    89.000000     18.000000
#
#        resolution_width  resolution_height    warranty
# count        893.000000         893.000000  893.000000
# mean        2035.393057        1218.324748    1.079507
# std          426.076009         326.756883    0.326956
# min         1080.000000         768.000000    0.000000
# ...

# %% [markdown]
# ##Load mean

# %% [markdown]
# Here we are load mean

# %%
import pandas as pd
df = pd.read_csv("/content/laptop price.csv")
df.mean()
# Out:
# <ipython-input-18-591627b772fb>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Unnamed: 0.1           467.135498
# Unnamed: 0             521.382979
# price                79907.409854
# spec_rating             69.379026
# display_size            15.173751
# resolution_width      2035.393057
# resolution_height     1218.324748
# warranty                 1.079507
# dtype: float64

# %% [markdown]
# ##loading median

# %% [markdown]
# here we are loading median

# %%
import pandas as pd
df = pd.read_csv("/content/laptop price.csv")
df.median()
# Out:
# <ipython-input-19-31779c001065>:3: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Unnamed: 0.1           467.000000
# Unnamed: 0             531.000000
# price                61990.000000
# spec_rating             69.323529
# display_size            15.600000
# resolution_width      1920.000000
# resolution_height     1080.000000
# warranty                 1.000000
# dtype: float64

# %% [markdown]
# ##LOAD MODE

# %% [markdown]
# Here we are loading mode

# %%
import pandas as pd
df = pd.read_csv("/content/laptop price.csv")
df.mode()
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand                  name    price  \
# 0               0           0    HP  Inspiron 3511 Laptop  49990.0
# 1               1           1   NaN  Inspiron 3525 Laptop      NaN
# 2               2           2   NaN                   NaN      NaN
# 3               3           3   NaN                   NaN      NaN
# 4               4           4   NaN                   NaN      NaN
# ..            ...         ...   ...                   ...      ...
# 888           926        1015   NaN                   NaN      NaN
# 889           927        1016   NaN                   NaN      NaN
# 890           928        1017   NaN                   NaN      NaN
# 891           929        1018   NaN                   NaN      NaN
# 892           930        1019   NaN                   NaN      NaN
#
#      spec_rating                     processor                   CPU   Ram  \
# 0      69.323529  12th Gen Intel Core i5 1235U  Quad Core, 8 Threads  16GB
# ...

# %% [markdown]
# ##STANDARD DEVIATION

# %% [markdown]
# Here we are finding standard deviation

# %%
import pandas as pd
df = pd.read_csv("/content/laptop price.csv")
df.std()
# Out:
# <ipython-input-21-e6b54a984ccd>:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Unnamed: 0.1           270.209769
# Unnamed: 0             299.916605
# price                60880.043823
# spec_rating              5.541555
# display_size             0.939095
# resolution_width       426.076009
# resolution_height      326.756883
# warranty                 0.326956
# dtype: float64

# %% [markdown]
# ## COUNT UNIQUE OF MAX COLUMN

# %%
import pandas as pd
df=pd.read_csv("/content/laptop price.csv")
df['price'].value_counts()
# Out:
# 49990     16
# 37990     13
# 59990     12
# 47990     11
# 64990     11
#           ..
# 58999      1
# 34250      1
# 80500      1
# 99990      1
# 189990     1
# Name: price, Length: 464, dtype: int64

# %% [markdown]
# ##LOAD SUM

# %% [markdown]
# here we are loading sum

# %%
import pandas as pd
df = pd.read_csv("/content/laptop price.csv")
df.sum()
# Out:
# Unnamed: 0.1                                                    417152
# Unnamed: 0                                                      465595
# brand                HPHPAcerLenovoAppleAcerDellAcerAsusSamsungLeno...
# name                 Victus 15-fb0157AX Gaming Laptop15s-fq5007TU L...
# price                                                         71357317
# spec_rating                                               61955.470588
# processor            5th Gen AMD Ryzen 5 5600H12th Gen Intel Core i...
# CPU                  Hexa Core, 12 ThreadsHexa Core (2P + 4E), 8 Th...
# Ram                  8GB8GB8GB16GB8GB8GB8GB16GB8GB16GB16GB4GB16GB4G...
# Ram_type             DDR4DDR4DDR4LPDDR5DDR4DDR4DDR4DDR5DDR4LPDDR5DD...
# ROM                  512GB512GB512GB512GB256GB512GB512GB512GB512GB5...
# ROM_type             SSDSSDSSDSSDSSDSSDSSDSSDSSDSSDSSDSSDSSDHard-Di...
# GPU                  4GB AMD Radeon RX 6500MIntel UHD GraphicsIntel...
# ...

# %% [markdown]
# ##Detecting Outliers

# %% [markdown]
# An outlier is a point or set of points that are different from other points.

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
sns.boxplot(x=df['spec_rating'])
# Out:
# <Axes: xlabel='spec_rating'>

# %%
sns.boxplot(x=df['warranty'])
# Out:
# <Axes: xlabel='warranty'>

# %% [markdown]
# ##Disk plot

# %% [markdown]
# Disk plot of price cloumn in given below

# %%
plt.figure(figsize=(6,3.2),dpi=150)
plt.rc('xtick', labelsize=6)
plt.rc('ytick', labelsize=8)
sns.distplot(df['price'])
plt.show()

# %% [markdown]
# ##HISTOGRAM

# %% [markdown]
# Histogram is a graph showing frequency distributions. It is a graph showing the number of observations within each given interval.
#
# ---

# %%
sns.histplot(df['price'],palette='hls')
plt.show()

# %%
sns.histplot(df['resolution_width'],palette='hls')
plt.show()

# %% [markdown]
# ##Scatterplot

# %% [markdown]
# We generally use scatter plots to find the correlation between two variables. Here the scatter plots are plotted between resolution_width and resolution_height and we can see the plot below.

# %%
import seaborn as sns
sns.scatterplot(data=df,x='resolution_width',y='resolution_height')
# Out:
# <Axes: xlabel='resolution_width', ylabel='resolution_height'>

# %% [markdown]
# ##Scatterplot

# %%
import seaborn as sns
sns.pairplot(df)

# %% [markdown]
# ## Line plot

# %% [markdown]
# This function is useful to plot lines using DataFrame’s values as coordinates.

# %%
sns.lineplot(x="brand", y="Unnamed: 0.1", data=df)
plt.show()

# %% [markdown]
# ##Pie Plot

# %% [markdown]
# A pie plot is a proportional representation of the numerical data in a column.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv("/content/laptop price.csv")
df.groupby(['brand']).sum().plot( kind='pie', y='Unnamed: 0.1',autopct='%1.0f%%')
plt.show()

# %% [markdown]
# ##Heat Maps

# %% [markdown]
# Heat Maps is a type of plot which is necessary when we need to find the dependent variables. One of the best way to find the relationship between the features can be done using heat maps.

# %%
import seaborn as sns
sns.heatmap(df.corr(numeric_only="price"),cmap='BrBG',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Hence the above are some of the steps involved in Exploratory data analysis, these are some general steps that you must follow in order to perform EDA. There are many more yet to come but for now, this is more than enough idea as to how to perform a good EDA given any data sets. Stay tuned for more updates.

# %% [markdown]
# ##Thank you.
